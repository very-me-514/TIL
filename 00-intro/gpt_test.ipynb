# %%
1

# %%
# 1. openAI와 통신할 SW 설치
# %pip install openai

# %%
prompt="""
마크다운이 뭐야?
"""

from openai import OpenAI
client = OpenAI(api_key='yours ')

response = client.responses.create(
    model='gpt-4.1-nano',
    input=prompt
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File c:\Users\marble\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\marble\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\marble\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...
