# %%
# firecrawl.ipynb

from firecrawl import Firecrawl

firecrawl = Firecrawl(api_key="fc-3dc80d5d0486456fa8c1b80d3800d530")

# Scrape a website:
doc = firecrawl.scrape("https://ko.wikipedia.org/wiki/%EC%97%94%EB%B9%84%EB%94%94%EC%95%84")
print(doc)
# Out:
# markdown='[본문으로 이동](https://ko.wikipedia.org/wiki/%EC%97%94%EB%B9%84%EB%94%94%EC%95%84#bodyContent)\n\n![](data:image/svg+xml,%3Csvg xmlns=%22http://www.w3.org/2000/svg%22 width=%2220%22 height=%2220%22 viewBox=%220 0 20 20%22%3E%3Ctitle%3Eclose%3C/title%3E%3Cpath d=%22M4.34 2.93l12.73 12.73-1.41 1.41L2.93 4.35z%22/%3E%3Cpath d=%22M17.07 4.34L4.34 17.07l-1.41-1.41L15.66 1.93z%22/%3E%3C/svg%3E)\n\n- [![](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/WP25_Short_lockup_knockout.png/40px-WP25_Short_lockup_knockout.png)](https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC_25 "위키백과:위키백과 25")[위키백과](https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC "위키백과") 가 25번째 생일을 맞았습니다! [위키백과 25주년 기념 포털](https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC_25 "위키백과:위키백과 25") 에 방문해 보세요!\n\n* * *\n\n- ![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Group_half.svg
# ...

# %%
from pprint import pprint

with open('./my-crawl.md', 'w', encoding='utf-8') as f:
    f.write(doc.markdown)

pprint(type(doc.markdown))
# Out:
# <class 'str'>

# %%
from firecrawl import Firecrawl

firecrawl = Firecrawl(api_key="fc-3dc80d5d0486456fa8c1b80d3800d530")

# Scrape a website:
doc = firecrawl.scrape("https://store.kyobobook.co.kr/bestseller/online/daily?page=1")
print(doc)
